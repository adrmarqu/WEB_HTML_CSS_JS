# %% [markdown]
# # Curso Completo de HTML y CSS 🚀
#
# Bienvenidos a este curso completo de HTML y CSS. En este curso, aprenderás desde los conceptos básicos hasta técnicas avanzadas de desarrollo web frontend.
#
# HTML: HyperText Markup Language
#
# CSS: Cascading Style Sheets
#
# ## Contenido del Curso
#
# 1. Configuración del Entorno HTML
# 2. Estructura Básica HTML5
# 3. Elementos de Texto HTML
# 4. Enlaces e Imágenes
# 5. Listas y Tablas
# 6. Formularios HTML
# 7. Introducción a CSS
# 8. Selectores CSS
# 9. Modelo de Caja y Layout
# 10. Flexbox y Grid
# 11. Diseño Responsivo
# 12. Transformaciones y Animaciones CSS
#
# ¡Empecemos! 🎯

# %% [markdown]
# # 1. Configuración del Entorno HTML 🛠️
#
# ## Editor de Código
#
# Para comenzar a desarrollar en HTML y CSS, necesitarás un buen editor de código. Algunas opciones recomendadas son:
#
# - **Visual Studio Code** (Recomendado)
# - **Sublime Text**
# - **Atom**
#
# **Configuración básica de VS Code para HTML y CSS**
#
# 1. Instalar VS Code
#
#    Descárgalo desde:
#    [https://code.visualstudio.com/](https://code.visualstudio.com/)
#
# 2. Extensiones esenciales
#    Abre VS Code → pestaña **Extensiones** (`Ctrl + Shift + X`) y busca estas:
#
#    - Live Server
#    - Live Preview
#    - Auto Rename Tag
#    - IntelliSense for CSS class names in HTML
#    - HTML Auto Close Tag
#    - Path Intellisense
#    - Color Highlight
#    - Htmltagwrap
#
# ## Herramientas del Navegador
#
# - Chrome DevTools (F12)
# - Firefox Developer Tools
# - Microsoft Edge DevTools
#
# ## Estructura de Carpetas
#
# Es importante mantener una estructura de carpetas organizada:
#
# ```
# mi-proyecto/
# ├── index.html
# ├── css/
# │   └── styles.css
# ├── images/
# │   └── (archivos de imágenes)
# └── js/
#     └── (archivos JavaScript)
# ```

# %% [markdown]
# # 2. Estructura Básica HTML5 📝
#
# ## Estructura Básica
#
# Todo documento HTML5 debe comenzar con la siguiente estructura:
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Mi Página Web</title>
#   </head>
#   <body>
#     <!-- Contenido de la página -->
#   </body>
# </html>
# ```
#
# ## Elementos del HEAD
#
# El elemento `<head>` contiene metadatos importantes:
#
# - `<meta charset="UTF-8">`: Especifica la codificación de caracteres
# - `<meta name="viewport">`: Configuración para dispositivos móviles
# - `<title>`: Título de la página
# - `<link>`: Para enlazar CSS externos
# - `<meta name="description">`: Descripción para motores de búsqueda
# - `<meta name="keywords">`: Palabras clave (menos relevante actualmente)
#
# ## Elementos del BODY
#
# El elemento `<body>` contiene todo el contenido visible:
#
# - Texto
# - Imágenes
# - Enlaces
# - Formularios
# - Otros elementos HTML
#
# ## Comentarios en HTML
#
# Los comentarios se escriben así:
#
# ```html
# <!-- Esto es un comentario -->
# <!--
#     También pueden ser
#     multilínea
# -->
# ```
#
# ## Indentación y Buenas Prácticas
#
# - Usa indentación consistente (2 o 4 espacios)
# - Cierra todas las etiquetas
# - Usa nombres descriptivos para clases e IDs
# - Mantén el código ordenado y legible

# %% [markdown]
# # 3. Elementos de Texto HTML 📚
#
# ## Encabezados
#
# HTML proporciona seis niveles de encabezados:
#
# ```html
# <h1>Encabezado 1</h1>
# <h2>Encabezado 2</h2>
# <h3>Encabezado 3</h3>
# <h4>Encabezado 4</h4>
# <h5>Encabezado 5</h5>
# <h6>Encabezado 6</h6>
# ```
#
# ## Párrafos y Formato de Texto
#
# ```html
# <p>Este es un párrafo normal.</p>
#
# <!-- Formato de texto -->
# <strong>Texto en negrita</strong>
# <em>Texto en cursiva</em>
# <u>Texto subrayado</u>
# <mark>Texto resaltado</mark>
# <small>Texto pequeño</small>
# <address>
#   Autor: Tu Nombre<br />
#   Email: <a href="mailto:tuemail@example.com">tuemail@example.com</a><br />
#   Dirección: Calle Falsa 123, Ciudad, País
# </address>
# abbr - <abbr title="abreviatura">abbr</abbr><br />
# código - <code>código</code><br />
# texto preformateado -
# <pre>
#
#             Línea 1
#             Línea 2 </pre
# >
# <br />
# del - <del>texto eliminado</del><br />
# ```
#
# ## Elementos Semánticos
#
# Los elementos semánticos ayudan a dar significado al contenido:
#
# ```html
# <article>
#   <header>
#     <h1>Título del Artículo</h1>
#   </header>
#   <section>
#     <p>Contenido principal...</p>
#   </section>
#   <footer>
#     <p>Pie del artículo</p>
#   </footer>
# </article>
#
# <nav>
#   <!-- Navegación -->
# </nav>
#
# <aside>
#   <!-- Contenido relacionado -->
# </aside>
#
# <main>
#   <!-- Contenido principal -->
# </main>
# ```
#
# ## Saltos de Línea y Separadores
#
# ```html
# <!-- Salto de línea -->
# <br />
#
# <!-- Línea horizontal -->
# <hr />
# ```
#
# ## Elementos de Cita
#
# ```html
# <!-- Cita en bloque -->
# <blockquote>
#   <p>Esta es una cita extensa que ocupa varios renglones.</p>
#   <cite>- Autor de la cita</cite>
# </blockquote>
#
# <!-- Cita en línea -->
# <q>Esta es una cita corta en línea</q>
# ```
#
# ## Pre-formateado
#
# ```html
# <pre>
#     Este texto mantiene
#     todos los espacios
#     y saltos de línea
#     exactamente como está escrito.
# </pre>
# ```

# %% [markdown]
# # 4. Enlaces e Imágenes 🔗
#
# ## Enlaces HTML
#
# Los enlaces se crean con la etiqueta `<a>`:
#
# ```html
# <!-- Enlace básico -->
# <a href="https://www.ejemplo.com">Visita mi sitio web</a>
#
# <!-- Enlace que se abre en una nueva pestaña -->
# <a href="https://www.ejemplo.com" target="_blank">Abrir en nueva pestaña</a>
#
# <!-- Enlace a una sección de la misma página -->
# <a href="#seccion1">Ir a sección 1</a>
#
# <!-- Enlace a un email -->
# <a href="mailto:correo@ejemplo.com">Enviar email</a>
#
# <!-- Enlace a un número telefónico -->
# <a href="tel:+123456789">Llamar</a>
# ```
#
# ## Rutas de Enlace
#
# ```html
# <!-- Ruta absoluta -->
# <a href="https://www.ejemplo.com/pagina.html">Enlace absoluto</a>
#
# <!-- Ruta relativa - mismo nivel -->
# <a href="contacto.html">Página de contacto</a>
#
# <!-- Ruta relativa - nivel superior -->
# <a href="../index.html">Volver al inicio</a>
#
# <!-- Ruta relativa - subcarpeta -->
# <a href="pages/about.html">Sobre nosotros</a>
# ```
#
# ## Imágenes
#
# Las imágenes se insertan con la etiqueta `<img>`:
#
# ```html
# <!-- Imagen básica -->
# <img src="imagen.jpg" alt="Descripción de la imagen" />
#
# <!-- Imagen con título -->
# <img src="foto.jpg" alt="Descripción" title="Título al pasar el mouse" />
# ```
#
# ## Picture y Source
#
# Para imágenes responsivas:
#
# ```html
# <picture>
#   <source media="(min-width: 650px)" srcset="img_pink_flowers.jpg" />
#   <source media="(min-width: 465px)" srcset="img_white_flower.jpg" />
#   <img src="img_orange_flowers.jpg" alt="Flores" />
# </picture>
# ```
#
# ## Imágenes como Enlaces
#
# ```html
# <a href="https://www.ejemplo.com">
#   <img src="boton.jpg" alt="Haz clic aquí" />
# </a>
# ```
#
# ## Figure y Figcaption
#
# Para imágenes con leyendas:
#
# ```html
# <figure>
#   <img src="imagen.jpg" alt="Una hermosa puesta de sol" />
#   <figcaption>Puesta de sol en la playa</figcaption>
# </figure>
# ```
#
# ## Mejores Prácticas
#
# - Siempre usa el atributo `alt`
# - Optimiza las imágenes para web
# - Usa formatos apropiados (JPG para fotos, PNG para transparencias)
# - Considera el tamaño de carga
# - Implementa imágenes responsivas cuando sea necesario

# %% [markdown]
# # 5. Listas y Tablas 📋
#
# ## Listas No Ordenadas
#
# ```html
# <ul>
#   <li>Elemento 1</li>
#   <li>Elemento 2</li>
#   <li>Elemento 3</li>
# </ul>
#
# <!-- Lista anidada -->
# <ul>
#   <li>
#     Frutas
#     <ul>
#       <li>Manzanas</li>
#       <li>Naranjas</li>
#       <li>Plátanos</li>
#     </ul>
#   </li>
# </ul>
# ```
#
# ## Listas Ordenadas
#
# ```html
# <ol>
#   <li>Primer paso</li>
#   <li>Segundo paso</li>
#   <li>Tercer paso</li>
# </ol>
#
# <!-- Lista ordenada con tipo específico -->
# <ol type="A">
#   <li>Opción A</li>
#   <li>Opción B</li>
#   <li>Opción C</li>
# </ol>
# ```
#
# ## Listas de Definición
#
# ```html
# <dl>
#   <dt>HTML</dt>
#   <dd>HyperText Markup Language</dd>
#
#   <dt>CSS</dt>
#   <dd>Cascading Style Sheets</dd>
# </dl>
# ```
#
# ## Tablas Básicas
#
# ```html
# <table>
#   <tr>
#     <th>Encabezado 1</th>
#     <th>Encabezado 2</th>
#   </tr>
#   <tr>
#     <td>Dato 1</td>
#     <td>Dato 2</td>
#   </tr>
# </table>
# ```
#
# ## Tablas Avanzadas
#
# ```html
# <table>
#   <thead>
#     <tr>
#       <th>Producto</th>
#       <th>Precio</th>
#       <th>Cantidad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Producto A</td>
#       <td>$10</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>Producto B</td>
#       <td>$20</td>
#       <td>3</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr>
#       <td>Total</td>
#       <td colspan="2">$110</td>
#     </tr>
#   </tfoot>
# </table>
# ```
#
# ## Atributos de Tabla
#
# - `colspan`: Combinar columnas
# - `rowspan`: Combinar filas
# - `border`: Borde de la tabla
# - `cellpadding`: Espacio dentro de las celdas
# - `cellspacing`: Espacio entre celdas
#
# ## Estilos de Tabla con CSS
#
# ```css
# table {
#   border-collapse: collapse;
#   width: 100%;
# }
#
# th,
# td {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: left;
# }
#
# th {
#   background-color: #f2f2f2;
# }
#
# tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# ```

# %% [markdown]
# # 6. Formularios HTML 📝
#
# ## Estructura Básica de un Formulario
#
# ```html
# <form action="/procesar.php" method="POST">
#   <!-- Elementos del formulario -->
#   <input type="submit" value="Enviar" />
# </form>
# ```
#
# ## Tipos de Input
#
# ```html
# <!-- Texto -->
# <input type="text" name="nombre" placeholder="Tu nombre" />
#
# <!-- Contraseña -->
# <input type="password" name="contraseña" />
#
# <!-- Email -->
# <input type="email" name="email" />
#
# <!-- Número -->
# <input type="number" name="edad" min="0" max="120" />
#
# <!-- Teléfono -->
# <input type="tel" name="telefono" />
#
# <!-- Fecha -->
# <input type="date" name="fecha" />
#
# <!-- Hora -->
# <input type="time" name="hora" />
#
# <!-- Checkbox -->
# <input type="checkbox" name="acepto" id="acepto" />
# <label for="acepto">Acepto los términos</label>
#
# <!-- Radio buttons -->
# <input type="radio" name="genero" value="masculino" id="masculino" />
# <label for="masculino">Masculino</label>
# <input type="radio" name="genero" value="femenino" id="femenino" />
# <label for="femenino">Femenino</label>
#
# <!-- Archivo -->
# <input type="file" name="documento" />
#
# <!-- Color -->
# <input type="color" name="color" />
#
# <!-- Rango -->
# <input type="range" name="volumen" min="0" max="100" />
# ```
#
# ## Elementos de Selección
#
# ```html
# <!-- Select simple -->
# <select name="pais">
#   <option value="">Seleccione un país</option>
#   <option value="es">España</option>
#   <option value="mx">México</option>
#   <option value="ar">Argentina</option>
# </select>
#
# <!-- Select múltiple -->
# <select name="lenguajes[]" multiple>
#   <option value="html">HTML</option>
#   <option value="css">CSS</option>
#   <option value="js">JavaScript</option>
# </select>
#
# <!-- Datalist -->
# <input list="navegadores" name="navegador" />
# <datalist id="navegadores">
#   <option value="Chrome"></option>
#   <option value="Firefox"></option>
#   <option value="Safari"></option>
# </datalist>
# ```
#
# ## Área de Texto
#
# ```html
# <textarea name="mensaje" rows="4" cols="50">
# Escribe tu mensaje aquí...
# </textarea>
# ```
#
# ## Agrupación y Etiquetado
#
# ```html
# <fieldset>
#   <legend>Información Personal</legend>
#
#   <label for="nombre">Nombre:</label>
#   <input type="text" id="nombre" name="nombre" required />
#
#   <label for="email">Email:</label>
#   <input type="email" id="email" name="email" required />
# </fieldset>
# ```
#
# ## Validación de Formularios
#
# ```html
# <!-- Campo requerido -->
# <input type="text" required />
#
# <!-- Patrón específico -->
# <input type="text" pattern="[A-Za-z]{3}" />
#
# <!-- Longitud mínima y máxima -->
# <input type="text" minlength="3" maxlength="10" />
#
# <!-- Rango numérico -->
# <input type="number" min="0" max="100" />
#
# <!-- Mensaje personalizado de validación -->
# <input
#   type="text"
#   required
#   oninvalid="this.setCustomValidity('Por favor, rellena este campo')"
#   oninput="this.setCustomValidity('')"
# />
# ```
#
# ## Estilos de Formulario con CSS
#
# ```css
# /* Estilo básico para inputs */
# input[type="text"] {
#   width: 100%;
#   padding: 12px 20px;
#   margin: 8px 0;
#   border: 1px solid #ccc;
#   border-radius: 4px;
# }
#
# /* Estilo para focus */
# input:focus {
#   border-color: #2196f3;
#   outline: none;
# }
#
# /* Estilo para campos inválidos */
# input:invalid {
#   border-color: #ff0000;
# }
#
# /* Estilo para botón */
# input[type="submit"] {
#   background-color: #4caf50;
#   color: white;
#   padding: 14px 20px;
#   border: none;
#   border-radius: 4px;
#   cursor: pointer;
# }
#
# input[type="submit"]:hover {
#   background-color: #45a049;
# }
# ```

# %% [markdown]
# # 7. Introducción a CSS 🎨
#
# ## Formas de Incluir CSS
#
# ### 1. CSS Interno (en el head)
#
# ```html
# <head>
#   <style>
#     p {
#       color: blue;
#       font-size: 16px;
#     }
#   </style>
# </head>
# ```
#
# ### 2. CSS Externo (archivo separado)
#
# ```html
# <head>
#   <link rel="stylesheet" href="styles.css" />
# </head>
# ```
#
# ### 3. CSS en línea
#
# ```html
# <p style="color: blue; font-size: 16px;">Este es un párrafo</p>
# ```
#
# ## Sintaxis CSS
#
# ```css
# selector {
#   propiedad: valor;
#   propiedad2: valor2;
# }
# ```
#
# ## Propiedades Básicas
#
# ### Colores
#
# ```css
# .elemento {
#   /* Nombre del color */
#   color: red;
#
#   /* Hexadecimal */
#   color: #ff0000;
#
#   /* RGB */
#   color: rgb(255, 0, 0);
#
#   /* RGBA (con transparencia) */
#   color: rgba(255, 0, 0, 0.5);
#
#   /* HSL */
#   color: hsl(0, 100%, 50%);
# }
# ```
#
# ### Texto
#
# ```css
# .texto {
#   font-family: Arial, sans-serif;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: center;
#   line-height: 1.5;
#   letter-spacing: 1px;
#   text-decoration: underline;
#   text-transform: uppercase;
# }
# ```
#
# ### Fondos
#
# ```css
# .fondo {
#   background-color: #f0f0f0;
#   background-image: url("imagen.jpg");
#   background-repeat: no-repeat;
#   background-position: center;
#   background-size: cover;
# }
# ```
#
# ### Bordes
#
# ```css
# .borde {
#   border-width: 1px;
#   border-style: solid;
#   border-color: #000;
#
#   /* Shorthand */
#   border: 1px solid #000;
#
#   border-radius: 5px;
# }
# ```
#
# ### Dimensiones
#
# ```css
# .dimensiones {
#   width: 100px;
#   height: 100px;
#   min-width: 50px;
#   max-width: 200px;
#   min-height: 50px;
#   max-height: 200px;
# }
# ```
#
# ## Unidades CSS
#
# ```css
# .unidades {
#   /* Unidades absolutas */
#   width: 100px; /* píxeles */
#   width: 1in; /* pulgadas */
#   width: 1cm; /* centímetros */
#
#   /* Unidades relativas */
#   width: 50%; /* porcentaje del contenedor */
#   font-size: 2em; /* relativo al tamaño de fuente del padre */
#   font-size: 2rem; /* relativo al tamaño de fuente del root */
#   width: 50vw; /* 50% del ancho de la ventana */
#   height: 50vh; /* 50% del alto de la ventana */
# }
# ```
#
# ## Comentarios en CSS
#
# ```css
# /* Esto es un comentario de una línea */
#
# /*
# Esto es un comentario
# de múltiples líneas
# en CSS
# */
# ```
#
# ## Cascada y Especificidad
#
# La especificidad determina qué estilo se aplica cuando hay conflictos:
#
# 1. Estilos en línea (1000)
# 2. IDs (100)
# 3. Clases, atributos y pseudoclases (10)
# 4. Elementos y pseudoelementos (1)
#
# ```css
# /* Especificidad: 1 */
# p {
#   color: blue;
# }
#
# /* Especificidad: 10 */
# .texto {
#   color: red;
# }
#
# /* Especificidad: 100 */
# #titulo {
#   color: green;
# }
# ```

# %% [markdown]
# # 8. Selectores CSS 🎯
#
# ## Selectores Básicos
#
# ### Selector Universal
#
# ```css
# * {
#   margin: 0;
#   padding: 0;
#   box-sizing: border-box;
# }
# ```
#
# ### Selector de Tipo
#
# ```css
# p {
#   color: blue;
# }
#
# div {
#   background-color: gray;
# }
# ```
#
# ### Selector de Clase
#
# ```css
# .destacado {
#   font-weight: bold;
# }
#
# /* Múltiples clases */
# .grande.rojo {
#   font-size: 20px;
#   color: red;
# }
# ```
#
# ### Selector de ID
#
# ```css
# #header {
#   background-color: black;
#   color: white;
# }
# ```
#
# ## Selectores Combinadores
#
# ### Descendiente (espacio)
#
# ```css
# /* Selecciona todos los p dentro de div */
# div p {
#   margin-bottom: 10px;
# }
# ```
#
# ### Hijo Directo (>)
#
# ```css
# /* Selecciona solo los p que son hijos directos de div */
# div > p {
#   border: 1px solid black;
# }
# ```
#
# ### Hermano Adyacente (+)
#
# ```css
# /* Selecciona el p que viene inmediatamente después de h2 */
# h2 + p {
#   font-style: italic;
# }
# ```
#
# ### Hermanos Generales (~)
#
# ```css
# /* Selecciona todos los p que vienen después de h2 */
# h2 ~ p {
#   color: gray;
# }
# ```
#
# ## Selectores de Atributo
#
# ### Atributo Presente
#
# ```css
# /* Elementos que tienen el atributo target */
# [target] {
#   color: red;
# }
# ```
#
# ### Atributo con Valor Específico
#
# ```css
# /* Enlaces que abren en nueva pestaña */
# [target="_blank"] {
#   text-decoration: underline;
# }
# ```
#
# ### Atributo que Contiene Palabra
#
# ```css
# /* Clase que contiene la palabra "button" */
# [class~="button"] {
#   cursor: pointer;
# }
# ```
#
# ## Pseudoclases
#
# ### Estados de Enlaces
#
# ```css
# a:link {
#   /* Enlaces no visitados */
#   color: blue;
# }
# a:visited {
#   /* Enlaces visitados */
#   color: purple;
# }
# a:hover {
#   /* Al pasar el mouse */
#   color: red;
# }
# a:active {
#   /* Al hacer clic */
#   color: green;
# }
# ```
#
# ### Estados de Elementos
#
# ```css
# input:focus {
#   border-color: blue;
# }
#
# input:disabled {
#   background-color: #ccc;
# }
#
# input:checked {
#   border: 2px solid green;
# }
# ```
#
# ### Posición en la Estructura
#
# ```css
# /* Primer hijo */
# :first-child {
#   font-weight: bold;
# }
#
# /* Último hijo */
# :last-child {
#   margin-bottom: 0;
# }
#
# /* Elemento específico */
# p:nth-child(2) {
#   color: red;
# }
#
# /* Patrón par/impar */
# tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# ```
#
# ## Pseudoelementos
#
# ### Antes y Después
#
# ```css
# .quote::before {
#   content: "«";
# }
#
# .quote::after {
#   content: "»";
# }
# ```
#
# ### Primera Letra y Línea
#
# ```css
# p::first-letter {
#   font-size: 200%;
#   font-weight: bold;
# }
#
# p::first-line {
#   color: blue;
# }
# ```
#
# ### Selección
#
# ```css
# ::selection {
#   background-color: yellow;
#   color: black;
# }
# ```
#
# ## Ejemplos de Combinaciones Complejas
#
# ```css
# /* Elementos con múltiples condiciones */
# .container > div.destacado[data-type="importante"] {
#   border: 2px solid red;
# }
#
# /* Selectores múltiples */
# h1,
# h2,
# h3 {
#   font-family: Arial, sans-serif;
# }
#
# /* Combinación de pseudoclases */
# .button:hover:not(:disabled) {
#   background-color: #0056b3;
# }
# ```

# %% [markdown]
# # 9. Modelo de Caja y Layout 📦
#
# ## El Modelo de Caja
#
# ### Componentes Básicos
#
# ```css
# .caja {
#   /* Contenido */
#   width: 200px;
#   height: 100px;
#
#   /* Relleno */
#   padding: 20px;
#
#   /* Borde */
#   border: 2px solid black;
#
#   /* Margen */
#   margin: 10px;
# }
# ```
#
# ### Box Sizing
#
# ```css
# /* Modelo de caja tradicional */
# .caja-content {
#   box-sizing: content-box;
# }
#
# /* Modelo de caja inclusivo */
# .caja-border {
#   box-sizing: border-box;
# }
# ```
#
# ### Márgenes
#
# ```css
# .elemento {
#   /* Todos los lados */
#   margin: 10px;
#
#   /* Superior/Inferior, Izquierda/Derecha */
#   margin: 10px 20px;
#
#   /* Superior, Izquierda/Derecha, Inferior */
#   margin: 10px 20px 15px;
#
#   /* Superior, Derecha, Inferior, Izquierda */
#   margin: 10px 20px 15px 25px;
#
#   /* Lados individuales */
#   margin-top: 10px;
#   margin-right: 20px;
#   margin-bottom: 15px;
#   margin-left: 25px;
# }
# ```
#
# ### Relleno (Padding)
#
# ```css
# .elemento {
#   /* Similar a margin */
#   padding: 10px;
#   padding: 10px 20px;
#   padding: 10px 20px 15px;
#   padding: 10px 20px 15px 25px;
#
#   padding-top: 10px;
#   padding-right: 20px;
#   padding-bottom: 15px;
#   padding-left: 25px;
# }
# ```
#
# ## Display
#
# ### Tipos de Display
#
# ```css
# /* Bloque */
# .bloque {
#   display: block;
# }
#
# /* En línea */
# .linea {
#   display: inline;
# }
#
# /* Bloque en línea */
# .bloque-linea {
#   display: inline-block;
# }
#
# /* Oculto */
# .oculto {
#   display: none;
# }
# ```
#
# ## Posicionamiento
#
# ### Static (Por defecto)
#
# ```css
# .estatico {
#   position: static;
# }
# ```
#
# ### Relative
#
# ```css
# .relativo {
#   position: relative;
#   top: 10px;
#   left: 20px;
# }
# ```
#
# ### Absolute
#
# ```css
# .absoluto {
#   position: absolute;
#   top: 0;
#   right: 0;
# }
# ```
#
# ### Fixed
#
# ```css
# .fijo {
#   position: fixed;
#   bottom: 20px;
#   right: 20px;
# }
# ```
#
# ### Sticky
#
# ```css
# .pegajoso {
#   position: sticky;
#   top: 0;
# }
# ```
#
# ## Float y Clear
#
# ### Float
#
# ```css
# .flotante {
#   float: left; /* o right */
#   width: 200px;
# }
# ```
#
# ### Clear
#
# ```css
# .limpiar {
#   clear: both; /* o left, right */
# }
# ```
#
# ## Z-Index y Capas
#
# ```css
# .capa1 {
#   z-index: 1;
# }
#
# .capa2 {
#   z-index: 2;
# }
# ```
#
# ## Overflow
#
# ```css
# .contenedor {
#   /* Ocultar contenido que se desborda */
#   overflow: hidden;
#
#   /* Mostrar barras de desplazamiento */
#   overflow: scroll;
#
#   /* Automático según necesidad */
#   overflow: auto;
#
#   /* Separado por eje */
#   overflow-x: hidden;
#   overflow-y: scroll;
# }
# ```
#
# ## Visibilidad
#
# ```css
# .elemento {
#   /* Oculto pero mantiene espacio */
#   visibility: hidden;
#
#   /* Visible (por defecto) */
#   visibility: visible;
# }
# ```
#
# ## Dimensiones
#
# ```css
# .elemento {
#   /* Ancho mínimo y máximo */
#   min-width: 100px;
#   max-width: 500px;
#
#   /* Alto mínimo y máximo */
#   min-height: 100px;
#   max-height: 500px;
#
#   /* Porcentajes */
#   width: 50%;
#   height: 100%;
# }
# ```

# %% [markdown]
# # 10. Flexbox y Grid 🔲
#
# ## Flexbox
#
# ### Contenedor Flex
#
# ```css
# .contenedor {
#   display: flex;
#
#   /* Dirección */
#   flex-direction: row; /* (por defecto) */
#   flex-direction: row-reverse;
#   flex-direction: column;
#   flex-direction: column-reverse;
#
#   /* Envolver elementos */
#   flex-wrap: nowrap; /* (por defecto) */
#   flex-wrap: wrap;
#   flex-wrap: wrap-reverse;
#
#   /* Atajo dirección y wrap */
#   flex-flow: row wrap;
#
#   /* Alineación horizontal */
#   justify-content: flex-start; /* (por defecto) */
#   justify-content: flex-end;
#   justify-content: center;
#   justify-content: space-between;
#   justify-content: space-around;
#   justify-content: space-evenly;
#
#   /* Alineación vertical */
#   align-items: stretch; /* (por defecto) */
#   align-items: flex-start;
#   align-items: flex-end;
#   align-items: center;
#   align-items: baseline;
#
#   /* Alineación de múltiples líneas */
#   align-content: stretch; /* (por defecto) */
#   align-content: flex-start;
#   align-content: flex-end;
#   align-content: center;
#   align-content: space-between;
#   align-content: space-around;
# }
# ```
#
# ### Elementos Flex
#
# ```css
# .elemento {
#   /* Orden */
#   order: 0; /* (por defecto) */
#
#   /* Capacidad de crecer */
#   flex-grow: 0; /* (por defecto) */
#
#   /* Capacidad de encogerse */
#   flex-shrink: 1; /* (por defecto) */
#
#   /* Tamaño base */
#   flex-basis: auto; /* (por defecto) */
#
#   /* Atajo para grow, shrink y basis */
#   flex: 0 1 auto; /* (por defecto) */
#   flex: 1; /* 1 1 0% */
#
#   /* Alineación individual */
#   align-self: auto; /* (por defecto) */
#   align-self: flex-start;
#   align-self: flex-end;
#   align-self: center;
#   align-self: baseline;
#   align-self: stretch;
# }
# ```
#
# ## Grid
#
# ### Contenedor Grid
#
# ```css
# .contenedor {
#   display: grid;
#
#   /* Definir columnas */
#   grid-template-columns: 100px 100px 100px;
#   grid-template-columns: repeat(3, 1fr);
#   grid-template-columns: 1fr 2fr 1fr;
#
#   /* Definir filas */
#   grid-template-rows: 100px auto;
#   grid-template-rows: repeat(2, 100px);
#
#   /* Espaciado */
#   gap: 10px; /* espaciado igual */
#   gap: 10px 20px; /* fila columna */
#
#   /* Áreas de grid */
#   grid-template-areas:
#     "header header header"
#     "sidebar main main"
#     "footer footer footer";
#
#   /* Alineación horizontal de ítems */
#   justify-items: start;
#   justify-items: end;
#   justify-items: center;
#   justify-items: stretch;
#
#   /* Alineación vertical de ítems */
#   align-items: start;
#   align-items: end;
#   align-items: center;
#   align-items: stretch;
#
#   /* Alineación del grid completo */
#   justify-content: start;
#   align-content: center;
# }
# ```
#
# ### Elementos Grid
#
# ```css
# .elemento {
#   /* Ubicación específica */
#   grid-column: 1 / 3; /* inicio / fin */
#   grid-column: 1 / span 2; /* inicio / cantidad */
#
#   grid-row: 1 / 3;
#   grid-row: 1 / span 2;
#
#   /* Atajo para columna y fila */
#   grid-area: 1 / 1 / 3 / 3; /* fila-inicio / columna-inicio / fila-fin / columna-fin */
#
#   /* Usar área nombrada */
#   grid-area: header;
#
#   /* Alineación individual horizontal */
#   justify-self: start;
#   justify-self: end;
#   justify-self: center;
#   justify-self: stretch;
#
#   /* Alineación individual vertical */
#   align-self: start;
#   align-self: end;
#   align-self: center;
#   align-self: stretch;
# }
# ```
#
# ### Funciones y Unidades Grid
#
# ```css
# .contenedor {
#   /* Función repeat */
#   grid-template-columns: repeat(3, 1fr);
#
#   /* Función minmax */
#   grid-template-columns: minmax(100px, 1fr);
#
#   /* Auto-fill y auto-fit */
#   grid-template-columns: repeat(auto-fill, minmax(200px, 1fr));
#   grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
#
#   /* Unidad fr */
#   grid-template-columns: 1fr 2fr 1fr;
# }
# ```
#
# ### Grid Responsivo
#
# ```css
# .contenedor {
#   /* Grid básico responsivo */
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(300px, 1fr));
#   gap: 20px;
#
#   /* Grid con áreas responsivas */
#   grid-template-areas:
#     "header"
#     "nav"
#     "main"
#     "sidebar"
#     "footer";
# }
#
# @media (min-width: 768px) {
#   .contenedor {
#     grid-template-areas:
#       "header header"
#       "nav main"
#       "sidebar main"
#       "footer footer";
#     grid-template-columns: 200px 1fr;
#   }
# }
# ```

# %% [markdown]
# # 11. Diseño Responsivo 📱
#
# ## Meta Viewport
#
# ```html
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# ```
#
# ## Media Queries
#
# ### Puntos de Ruptura Comunes
#
# ```css
# /* Móvil primero (por defecto) */
# /* Estilos base aquí */
#
# /* Tablets */
# @media (min-width: 768px) {
#   /* Estilos para tablets */
# }
#
# /* Escritorio */
# @media (min-width: 1024px) {
#   /* Estilos para escritorio */
# }
#
# /* Pantallas grandes */
# @media (min-width: 1200px) {
#   /* Estilos para pantallas grandes */
# }
# ```
#
# ### Tipos de Media
#
# ```css
# /* Por tipo de dispositivo */
# @media screen {
#   /* Solo para pantallas */
# }
#
# @media print {
#   /* Solo para impresión */
# }
#
# /* Por orientación */
# @media (orientation: landscape) {
#   /* Modo horizontal */
# }
#
# @media (orientation: portrait) {
#   /* Modo vertical */
# }
#
# /* Por características específicas */
# @media (hover: hover) {
#   /* Solo si el dispositivo soporta hover */
# }
# ```
#
# ## Unidades Relativas
#
# ### Viewport
#
# ```css
# .elemento {
#   /* Relativo al ancho del viewport */
#   width: 50vw;
#
#   /* Relativo al alto del viewport */
#   height: 100vh;
#
#   /* Relativo al mínimo del viewport */
#   width: 50vmin;
#
#   /* Relativo al máximo del viewport */
#   height: 100vmax;
# }
# ```
#
# ### Em y Rem
#
# ```css
# html {
#   font-size: 16px; /* Base para rem */
# }
#
# .elemento {
#   /* Relativo al tamaño de fuente del padre */
#   font-size: 1.5em;
#   margin: 1em;
#
#   /* Relativo al tamaño de fuente del root */
#   font-size: 1.5rem;
#   margin: 1rem;
# }
# ```
#
# ## Imágenes Responsivas
#
# ### Picture Element
#
# ```html
# <picture>
#   <source media="(min-width: 1200px)" srcset="imagen-grande.jpg" />
#   <source media="(min-width: 768px)" srcset="imagen-mediana.jpg" />
#   <img src="imagen-pequeña.jpg" alt="Descripción" />
# </picture>
# ```
#
# ### Imágenes Responsivas con srcset
#
# ```html
# <img
#   src="imagen-pequeña.jpg"
#   srcset="
#     imagen-pequeña.jpg 300w,
#     imagen-mediana.jpg 600w,
#     imagen-grande.jpg  900w
#   "
#   sizes="(max-width: 320px) 280px,
#             (max-width: 640px) 580px,
#             800px"
#   alt="Descripción"
# />
# ```
#
# ## Layout Responsivo
#
# ### Grids Responsivos
#
# ```css
# .grid-container {
#   display: grid;
#   /* Mobile: 1 columna */
#   grid-template-columns: 1fr;
#   gap: 20px;
# }
#
# @media (min-width: 768px) {
#   .grid-container {
#     /* Tablet: 2 columnas */
#     grid-template-columns: repeat(2, 1fr);
#   }
# }
#
# @media (min-width: 1024px) {
#   .grid-container {
#     /* Desktop: 3 columnas */
#     grid-template-columns: repeat(3, 1fr);
#   }
# }
# ```
#
# ### Flexbox Responsivo
#
# ```css
# .flex-container {
#   display: flex;
#   flex-direction: column;
# }
#
# @media (min-width: 768px) {
#   .flex-container {
#     flex-direction: row;
#   }
# }
# ```
#
# ## Navegación Responsiva
#
# ### Menú Hamburguesa
#
# ```css
# .nav-toggle {
#   display: block;
# }
#
# .nav-menu {
#   display: none;
# }
#
# .nav-menu.active {
#   display: block;
# }
#
# @media (min-width: 768px) {
#   .nav-toggle {
#     display: none;
#   }
#
#   .nav-menu {
#     display: flex;
#   }
# }
# ```
#
# ## Tipografía Responsiva
#
# ```css
# html {
#   font-size: 16px;
# }
#
# h1 {
#   font-size: 1.5rem;
# }
#
# @media (min-width: 768px) {
#   html {
#     font-size: 18px;
#   }
#
#   h1 {
#     font-size: 2rem;
#   }
# }
#
# @media (min-width: 1200px) {
#   html {
#     font-size: 20px;
#   }
#
#   h1 {
#     font-size: 2.5rem;
#   }
# }
# ```
#
# ## Mejores Prácticas
#
# ### Mobile First
#
# ```css
# /* Estilo base para móvil */
# .elemento {
#   width: 100%;
# }
#
# /* Ajustes para pantallas más grandes */
# @media (min-width: 768px) {
#   .elemento {
#     width: 50%;
#   }
# }
# ```
#
# ### Performance
#
# ```css
# /* Evitar animaciones en móvil */
# @media (max-width: 768px) {
#   .animacion {
#     animation: none;
#     transition: none;
#   }
# }
#
# /* Cargar imágenes más pequeñas en móvil */
# .imagen-bg {
#   background-image: url("imagen-pequeña.jpg");
# }
#
# @media (min-width: 768px) {
#   .imagen-bg {
#     background-image: url("imagen-grande.jpg");
#   }
# }
# ```

# %% [markdown]
# # 12. Transformaciones y Animaciones CSS 🎭
#
# ## Transformaciones
#
# ### Transform
#
# ```css
# .elemento {
#   /* Traslación */
#   transform: translate(50px, 100px);
#   transform: translateX(50px);
#   transform: translateY(100px);
#
#   /* Rotación */
#   transform: rotate(45deg);
#   transform: rotateX(45deg);
#   transform: rotateY(45deg);
#   transform: rotateZ(45deg);
#
#   /* Escala */
#   transform: scale(1.5);
#   transform: scaleX(2);
#   transform: scaleY(0.5);
#
#   /* Sesgo */
#   transform: skew(10deg, 20deg);
#   transform: skewX(10deg);
#   transform: skewY(20deg);
#
#   /* Combinaciones */
#   transform: translate(50px, 100px) rotate(45deg) scale(1.5);
# }
# ```
#
# ### Transform Origin
#
# ```css
# .elemento {
#   transform-origin: center; /* (por defecto) */
#   transform-origin: top left;
#   transform-origin: bottom right;
#   transform-origin: 100px 200px;
# }
# ```
#
# ## Transiciones
#
# ### Propiedades Básicas
#
# ```css
# .elemento {
#   /* Propiedad individual */
#   transition-property: background-color;
#   transition-duration: 0.3s;
#   transition-timing-function: ease;
#   transition-delay: 0.1s;
#
#   /* Atajo */
#   transition: background-color 0.3s ease 0.1s;
#
#   /* Múltiples transiciones */
#   transition: background-color 0.3s ease, transform 0.5s ease-in-out;
# }
# ```
#
# ### Timing Functions
#
# ```css
# .elemento {
#   transition-timing-function: linear;
#   transition-timing-function: ease;
#   transition-timing-function: ease-in;
#   transition-timing-function: ease-out;
#   transition-timing-function: ease-in-out;
#   transition-timing-function: cubic-bezier(0.42, 0, 0.58, 1);
# }
# ```
#
# ## Animaciones
#
# ### Keyframes
#
# ```css
# @keyframes slide-in {
#   0% {
#     transform: translateX(-100%);
#     opacity: 0;
#   }
#   100% {
#     transform: translateX(0);
#     opacity: 1;
#   }
# }
#
# @keyframes rotate {
#   from {
#     transform: rotate(0deg);
#   }
#   to {
#     transform: rotate(360deg);
#   }
# }
# ```
#
# ### Propiedades de Animación
#
# ```css
# .elemento {
#   /* Nombre y duración */
#   animation-name: slide-in;
#   animation-duration: 1s;
#
#   /* Timing function */
#   animation-timing-function: ease-out;
#
#   /* Retraso */
#   animation-delay: 0.5s;
#
#   /* Iteraciones */
#   animation-iteration-count: infinite;
#   animation-iteration-count: 3;
#
#   /* Dirección */
#   animation-direction: normal;
#   animation-direction: reverse;
#   animation-direction: alternate;
#   animation-direction: alternate-reverse;
#
#   /* Estado final */
#   animation-fill-mode: none;
#   animation-fill-mode: forwards;
#   animation-fill-mode: backwards;
#   animation-fill-mode: both;
#
#   /* Estado de reproducción */
#   animation-play-state: running;
#   animation-play-state: paused;
#
#   /* Atajo */
#   animation: slide-in 1s ease-out 0.5s infinite;
# }
# ```
#
# ## Ejemplos Prácticos
#
# ### Botón con Hover
#
# ```css
# .button {
#   padding: 10px 20px;
#   background-color: #007bff;
#   color: white;
#   border: none;
#   transition: all 0.3s ease;
# }
#
# .button:hover {
#   background-color: #0056b3;
#   transform: scale(1.1);
# }
# ```
#
# ### Tarjeta con Flip
#
# ```css
# .card {
#   width: 200px;
#   height: 300px;
#   position: relative;
#   perspective: 1000px;
# }
#
# .card-inner {
#   position: relative;
#   width: 100%;
#   height: 100%;
#   transform-style: preserve-3d;
#   transition: transform 0.6s;
# }
#
# .card:hover .card-inner {
#   transform: rotateY(180deg);
# }
#
# .card-front,
# .card-back {
#   position: absolute;
#   width: 100%;
#   height: 100%;
#   backface-visibility: hidden;
# }
#
# .card-back {
#   transform: rotateY(180deg);
# }
# ```
#
# ### Loader Animado
#
# ```css
# .loader {
#   width: 50px;
#   height: 50px;
#   border: 5px solid #f3f3f3;
#   border-top: 5px solid #3498db;
#   border-radius: 50%;
#   animation: spin 1s linear infinite;
# }
#
# @keyframes spin {
#   0% {
#     transform: rotate(0deg);
#   }
#   100% {
#     transform: rotate(360deg);
#   }
# }
# ```
#
# ### Menú Hamburguesa Animado
#
# ```css
# .hamburger {
#   width: 30px;
#   height: 20px;
#   position: relative;
#   cursor: pointer;
# }
#
# .hamburger-line {
#   width: 100%;
#   height: 2px;
#   background-color: black;
#   position: absolute;
#   transition: all 0.3s ease;
# }
#
# .hamburger-line:nth-child(1) {
#   top: 0;
# }
# .hamburger-line:nth-child(2) {
#   top: 50%;
# }
# .hamburger-line:nth-child(3) {
#   top: 100%;
# }
#
# .hamburger.active .hamburger-line:nth-child(1) {
#   transform: translateY(10px) rotate(45deg);
# }
#
# .hamburger.active .hamburger-line:nth-child(2) {
#   opacity: 0;
# }
#
# .hamburger.active .hamburger-line:nth-child(3) {
#   transform: translateY(-10px) rotate(-45deg);
# }
# ```
